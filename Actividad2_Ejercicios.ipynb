# %%
ventas_i, ventas_f = 200000, 260000
costos_i, costos_f = 120000, 150000

pct_ventas = (ventas_f - ventas_i) / ventas_i * 100
pct_costos = (costos_f - costos_i) / costos_i * 100

utilidad_i = ventas_i - costos_i
utilidad_f = ventas_f - costos_f
pct_utilidad = (utilidad_f - utilidad_i) / utilidad_i * 100

print(f"a) Aumento en ventas: {pct_ventas}%")
print(f"b) Aumento en costos: {pct_costos}%")
print(f"c) Utilidad inicial: {utilidad_i}, final: {utilidad_f}, aumento: {pct_utilidad}%")
# Out:
# a) Aumento en ventas: 30.0%
# b) Aumento en costos: 25.0%
# c) Utilidad inicial: 80000, final: 110000, aumento: 37.5%

# %%
hombres, mujeres = 400, 600
pct_h, pct_m = 0.35, 0.45

aprueban_h = hombres * pct_h
aprueban_m = mujeres * pct_m
total_aprueban = aprueban_h + aprueban_m
total = hombres + mujeres

pct_global = total_aprueban / total * 100
pct_simple = (pct_h*100 + pct_m*100) / 2

print(f"Aprueban hombres: {aprueban_h}")
print(f"Aprueban mujeres: {aprueban_m}")
print(f"Aprobación global (ponderada): {pct_global}%")
print(f"Promedio simple (incorrecto): {pct_simple}%")
# Out:
# Aprueban hombres: 140.0
# Aprueban mujeres: 270.0
# Aprobación global (ponderada): 41.0%
# Promedio simple (incorrecto): 40.0%

# %%
# Hospital A
A_bajo_c, A_bajo_e = 100, 98
A_alto_c, A_alto_e = 100, 60

# Hospital B
B_bajo_c, B_bajo_e = 300, 288
B_alto_c, B_alto_e = 100, 55

tasa_A_bajo = A_bajo_e / A_bajo_c * 100
tasa_A_alto = A_alto_e / A_alto_c * 100
tasa_A_global = (A_bajo_e + A_alto_e) / (A_bajo_c + A_alto_c) * 100

tasa_B_bajo = B_bajo_e / B_bajo_c * 100
tasa_B_alto = B_alto_e / B_alto_c * 100
tasa_B_global = (B_bajo_e + B_alto_e) / (B_bajo_c + B_alto_c) * 100

print(f"Hospital A -> bajo riesgo: {tasa_A_bajo}%, alto riesgo: {tasa_A_alto}%, global: {tasa_A_global}%")
print(f"Hospital B -> bajo riesgo: {tasa_B_bajo}%, alto riesgo: {tasa_B_alto}%, global: {tasa_B_global}%")
# Out:
# Hospital A -> bajo riesgo: 98.0%, alto riesgo: 60.0%, global: 79.0%
# Hospital B -> bajo riesgo: 96.0%, alto riesgo: 55.00000000000001%, global: 85.75%

# %%
prob_siniestro = 0.02
pago_siniestro = 2000
prima = 50

pago_esperado = prob_siniestro * pago_siniestro
ganancia_esperada = prima - pago_esperado

# Verificación por los dos escenarios
ganancia_sin_siniestro = prima
ganancia_con_siniestro = prima - pago_siniestro
ev_verificacion = (1 - prob_siniestro) * ganancia_sin_siniestro + prob_siniestro * ganancia_con_siniestro

print(f"Pago esperado por siniestro: ${pago_esperado}")
print(f"Ganancia esperada por póliza: ${ganancia_esperada}")
print(f"Verificación (EV por escenarios): ${ev_verificacion}")
# Out:
# Pago esperado por siniestro: $40.0
# Ganancia esperada por póliza: $10.0
# Verificación (EV por escenarios): $10.0

# %%
gasto_fijo = 180
pendiente = 0.25

# c) Aumento en gasto si el ingreso sube $1000
aumento_ingreso = 1000
aumento_gasto = pendiente * aumento_ingreso

# d) Gasto estimado e ingreso de $2000
ingreso = 2000
gasto_estimado = gasto_fijo + pendiente * ingreso
pct_ingreso = gasto_estimado / ingreso * 100

print(f"c) Aumento en el gasto por $1000 más de ingreso: ${aumento_gasto}")
print(f"d) Gasto estimado para ingreso de $2000: ${gasto_estimado}")
print(f"   Porcentaje del ingreso que representa: {pct_ingreso}%")
# Out:
# c) Aumento en el gasto por $1000 más de ingreso: $250.0
# d) Gasto estimado para ingreso de $2000: $680.0
#    Porcentaje del ingreso que representa: 34.0%
